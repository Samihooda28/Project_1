# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
import numpy as np
from itertools import cycle, islice

# %%
acrash= "Data/Crash_Data.csv"
acrash_df=pd.read_csv(acrash,dtype='unicode')
acrash_df
# Out:
#        Crash ID State Month  Year    Dayweek   Time Crash Type  \
# 0      20212133   Vic     9  2021     Sunday   0:30     Single
# 1      20214022    SA     9  2021   Saturday  23:31   Multiple
# 2      20212096   Vic     9  2021   Saturday  23:00     Single
# 3      20212145   Vic     9  2021   Saturday  22:25     Single
# 4      20212075   Vic     9  2021   Saturday   5:15     Single
# ...         ...   ...   ...   ...        ...    ...        ...
# 52838  19891246   NSW     1  1989  Wednesday  17:05     Single
# 52839  19895088    WA     1  1989     Monday   6:00     Single
# 52840  19895088    WA     1  1989     Monday   6:00     Single
# 52841  19895088    WA     1  1989     Monday   6:00     Single
# 52842  19896063   Tas     1  1989    Tuesday  12:40   Multiple
#
#       Bus Involvement Heavy Rigid Truck Involvement  \
# 0                 NaN                           NaN
# 1                  No                            No
# 2                 NaN                           NaN
# 3                 NaN                           NaN
# 4                 NaN                           NaN
# ...               ...                           ...
# 52838             Yes                           NaN
# 52839              No                           NaN
# 52840              No                           NaN
# 52841              No                           NaN
# 52842              No                           NaN
#
#       Articulated Truck Involvement  ... Age  National Remoteness Areas  \
# 0                               NaN  ...  38   Inner Regional Australia
# 1                                No  ...  28  Major Cities of Australia
# 2                               NaN  ...  19   Inner Regional Australia
# 3                               NaN  ...  23   Outer Regional Australia
# 4                               NaN  ...  46  Major Cities of Australia
# ...                             ...  ...  ..                        ...
# 52838                            No  ...   5                        NaN
# 52839                            No  ...  19                        NaN
# 52840                            No  ...  17                        NaN
# 52841                            No  ...  17                        NaN
# 52842                            No  ...  63                        NaN
#
#                 SA4 Name 2016 National LGA Name 2017 National Road Type  \
# 0      Melbourne - Outer East       Yarra Ranges (S)      Arterial Road
# 1            Adelaide - North           Playford (C)                NaN
# 2                        Hume        Wangaratta (RC)        Access road
# 3                        Hume        Wangaratta (RC)      Arterial Road
# 4      Melbourne - South East              Casey (C)         Local Road
# ...                       ...                    ...                ...
# 52838                     NaN                    NaN                NaN
# 52839                     NaN                    NaN                NaN
# 52840                     NaN                    NaN                NaN
# 52841                     NaN                    NaN                NaN
# 52842                     NaN                    NaN                NaN
#
#       Christmas Period Easter Period Age Group Day of week Time of day
# 0                   No            No  26_to_39     Weekend       Night
# 1                   No            No  26_to_39     Weekend       Night
# 2                   No            No  17_to_25     Weekend       Night
# 3                   No            No  17_to_25     Weekend       Night
# 4                   No            No  40_to_64     Weekend       Night
# ...                ...           ...       ...         ...         ...
# 52838               No            No   0_to_16     Weekday         Day
# 52839              Yes            No  17_to_25     Weekday         Day
# 52840              Yes            No  17_to_25     Weekday         Day
# 52841              Yes            No  17_to_25     Weekday         Day
# 52842               No            No  40_to_64     Weekday         Day
#
# [52843 rows x 23 columns]

# %%
acrash_new=acrash_df[['Crash ID','State', 'Month', 'Year', 'Dayweek', 'Time', 'Crash Type', 'Speed Limit','Road User','Gender','Age','National Remoteness Areas','Age Group','Time of day']]
acrash_new.head()
# Out:
#    Crash ID State Month  Year   Dayweek   Time Crash Type Speed Limit  \
# 0  20212133   Vic     9  2021    Sunday   0:30     Single         NaN
# 1  20214022    SA     9  2021  Saturday  23:31   Multiple         110
# 2  20212096   Vic     9  2021  Saturday  23:00     Single         NaN
# 3  20212145   Vic     9  2021  Saturday  22:25     Single         NaN
# 3982  Other/-9  Female  21           Remote Australia     17_to_25         Day
# 3986  Other/-9  Female  28           Remote Australia     26_to_39         Day
# 4303  Other/-9    Male  94  Major Cities of Australia  75_or_older         Day
# 4691  Other/-9    Male  21   Outer Regional Australia     17_to_25       Night
# 4692  Other/-9    Male  21   Outer Regional Australia     17_to_25       Night
# 4911  Other/-9    Male  91  Major Cities of Australia  75_or_older         Day
# 5116  Other/-9  Female   0   Outer Regional Australia      0_to_16       Night
# 5254  Other/-9  Female  98  Major Cities of Australia  75_or_older         Day
# 5286  Other/-9    Male  47   Outer Regional Australia     40_to_64         Day
# 5447  Other/-9  Female  61   Outer Regional Australia     40_to_64         Day
# 5852  Other/-9    Male  23  Major Cities of Australia     17_to_25         Day
# 6064  Other/-9    Male   5      Very Remote Australia      0_to_16         Day
# 7316  Other/-9    Male  35   Outer Regional Australia     26_to_39       Night
# 7317  Other/-9    Male  35   Outer Regional Australia     26_to_39       Night
# 7831  Other/-9    Male  88   Inner Regional Australia  75_or_older         Day

# %%
acrash_new_df = acrash_new_df[acrash_new_df['Road User'] != 'Other/-9']
acrash_new_df = acrash_new_df[acrash_new_df['Speed Limit'] != 'Unspecified']

# %%
acrash_new_df['Speed Limit']=acrash_new_df['Speed Limit'].replace(['<40'],'40')

# %%
acrash_new_df.reset_index(drop=True)
# Out:
#       Crash ID State Month  Year    Dayweek   Time Crash Type Speed Limit  \
# 0     20214022    SA     9  2021   Saturday  23:31   Multiple         110
# 1     20213034   Qld     9  2021   Saturday   4:00   Multiple         100
# 2     20213092   Qld     9  2021   Saturday   2:00     Single          60
# 3     20214053    SA     9  2021   Thursday  21:00     Single          80
# 4     20213178   Qld     9  2021     Sunday  21:00   Multiple          50
# ...        ...   ...   ...   ...        ...    ...        ...         ...
# 6761  20144083    SA     1  2014     Friday  11:10   Multiple         110
# 6762  20145108    WA     1  2014  Wednesday  11:47     Single         100
# 6763  20144022    SA     1  2014     Monday   9:35     Single          50
# 6764  20145072    WA     1  2014    Tuesday  21:30     Single         110
# 6765  20144007    SA     1  2014    Tuesday  20:00     Single          50
#
#              Road User  Gender Age  National Remoteness Areas    Age Group  \
# 0           Pedestrian  Female  28  Major Cities of Australia     26_to_39
# 1     Motorcycle rider    Male  19  Major Cities of Australia     17_to_25
# 2               Driver    Male  47  Major Cities of Australia     40_to_64
# 3               Driver    Male  24   Inner Regional Australia     17_to_25
# 4     Motorcycle rider    Male  52  Major Cities of Australia     40_to_64
# ...                ...     ...  ..                        ...          ...
# 6761         Passenger    Male  40   Outer Regional Australia     40_to_64
# 6762  Motorcycle rider    Male  46  Major Cities of Australia     40_to_64
# 6763        Pedestrian  Female  82  Major Cities of Australia  75_or_older
# 6764            Driver    Male  84           Remote Australia  75_or_older
# 6765        Pedestrian    Male  82  Major Cities of Australia  75_or_older
#
#      Time of day
# 0          Night
# 1          Night
# 2          Night
# 3          Night
# 4          Night
# ...          ...
# 6761         Day
# 6762         Day
# 6763         Day
# 6764       Night
# 6765       Night
#
# [6766 rows x 14 columns]

# %%
acrash_new_df.to_csv("Data/cleaned_crash_data.csv", 
                    encoding="utf-8" , index=False, header=True)

# %%
state_count=acrash_new_df['State'].value_counts()
x_axis=state_count.index.values
y_axis=state_count.values

my_colors_state = list(islice(cycle(['b', 'r', 'g', 'y', 'k','m','c','brown']), None, len(acrash_new_df['State'])))

plt.bar(x_axis,y_axis,align='center', color = my_colors_state)
plt.xlabel('State')
plt.ylabel('Number of Road Crash Fatalities')
plt.title('Australian Road Accident Fatalities by State 2014-2021')
plt.savefig('Data/Images/State_Crash.png')
plt.show()

# %%
remote_count=acrash_new_df['National Remoteness Areas'].value_counts()
x_axis=remote_count.index.values
y_axis=remote_count.values

my_colors_remote_area = list(islice(cycle([ 'g', 'y', 'k','m','c']), None, len(acrash_new_df['National Remoteness Areas'])))

plt.bar(x_axis,y_axis,align='center',color = my_colors_remote_area)
plt.xlabel('National Remoteness Areas')
plt.ylabel('Number of Road Crash Fatalities')
plt.title('Australian Road Accident Fatalities by Area Remoteness 2014-2021')
plt.xticks(rotation="vertical")
plt.savefig('Data/Images/Remote_area_numbers.png')
plt.show()

# %%
acrash_new_df['Year']=acrash_new_df['Year'].astype(int)
remote_count=acrash_new_df['Year'].value_counts()
x_axis=remote_count.index.values
y_axis=remote_count.values

my_colors_year = list(islice(cycle(['b', 'r', 'g', 'y', 'k','m','c','brown']), None, len(acrash_new_df['State'])))

plt.bar(x_axis,y_axis, align='center',color=my_colors_year)
plt.xlabel('Years')
plt.ylabel('# of crash')
plt.ylabel('Number of Road Crash Fatalities')
plt.title('Australian Road Accident Fatalities by Year 2014-2021')
plt.xticks(rotation="vertical")
plt.savefig('Data/Images/Number of crash in Year .png')
plt.show()

# %%
year_data = acrash_new_df["Year"].value_counts()
year_data = year_data.sort_index()
year_data
plt.plot(year_data,marker='o')
plt.xlabel('Year')
plt.ylabel('Number of Road Crash Fatalities')
plt.title('Australian Road Accident Fatalities by Year 2014-2021')
plt.savefig('Data/Images/Number of crash in Year(Line Chart) .png')
plt.show()

# %%
speed_agg=acrash_new_df.groupby(['State'])[['Speed Limit']].agg(['mean', 'median', 'var', 'std', 'sem'])
speed_agg
# Out:
#       Speed Limit
#              mean median         var        std       sem
# State
# ACT     75.294118   80.0  285.411765  16.894134  2.365652
# NSW     80.021683   80.0  467.808640  21.628884  0.450406
# NT      95.369650  100.0  644.491732  25.386842  1.583588
# Qld     83.148936   90.0  373.886208  19.336137  0.630675
# SA      85.046481  100.0  583.475230  24.155232  0.880266
# Tas     84.055118  100.0  510.368491  22.591337  1.417507
# Vic     81.373668   80.0  406.432238  20.160165  0.556156
# WA      88.035915  100.0  527.935787  22.976853  0.769754

# %%
acrash_new_df['Speed Limit']=acrash_new_df['Speed Limit'].astype(int)
speed_limit=acrash_new_df['Speed Limit'].value_counts()
speed=speed_limit.index.values
count=speed_limit.values

plt.bar(speed,count)

plt.xlabel('Speed')
plt.ylabel('Number of Road Crash Fatalities')
plt.title('Australian Road Accident Fatalities ( Speed Limit) 2014-2021')
# plt.xlim(0,140)
# plt.ylim(0,2400)
plt.savefig('Data/Images/Speed v Crash.png')
plt.show()

# %%
speed_data = acrash_new_df["Speed Limit"].value_counts()
speed_data = speed_data.sort_index()
speed_data
plt.plot(speed_data,marker='*')
plt.xlabel('Speed')
plt.ylabel('Number of Road Crash Fatalities')
plt.title('Australian Road Accident Fatalities ( Speed Limit) 2014-2021')
plt.savefig('Data/Images/Speed v Crash.png')
plt.show()

# %%
correlation=st.pearsonr(speed,count)
print(f" The correlation between speed and number of crash is {round(correlation[0],2)}")

# %%
(slope, intercept,rvalue, pvalue, stderr)= linregress(speed,count)
regress_values=speed* slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"

plt.scatter(speed,count,color='b')
plt.plot(speed, regress_values, color='red')
plt.annotate(line_eq, (18,37), fontsize=16)
plt.xlabel("Speed")
plt.ylabel('Number of Road Crash Fatalities')
plt.title('Australian Road Accident Fatalities ( Speed Limit) 2014-2021')
print(f"The r-squared is: {round(rvalue**2,3)}")
plt.savefig('Data/Images/Speed v # of Crash 2.png')
plt.show()
# Out:
# The r-squared is: 0.186
